# %%
print("wellcome")
# Out:
# Running cells with 'Python 3.13.2' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/YDO hello/AppData/Local/Programs/Python/Python313/python.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
#  # Mohsin Arif
# ![IMG_20161223_192703-2.jpg](attachment:IMG_20161223_192703-2.jpg)
#  ## [Gmail](mohsinarif2009@hotmail.com) | [Linkedin](https://www.linkedin.com/in/mohsin-arif-57b875156/) | [GitHUb](https://github.com/MohsinML/MOHSIN-ARIF) [📲phone](+923345066142)
#
#  ## 📌 Professional Summary
#
#  ### Enthusiastic and detail-oriented Python Developer with a strong foundation in Python programming, version control (Git & GitHub), and development tools like VS Code. Adept at writing clean, efficient, and well-documented code using Markdown for project documentation. Passionate about learning new technologies and problem-solving in a collaborative environment. Looking to leverage my skills in software development, debugging, and team collaboration to contribute effectively to dynamic projects.
#
#  ## 👨🏻‍🎓 Educations
#
#  ### ● Bsc Electrical Engineering from UET 2019
#
#  ### ● D.A.E Electronics From Wah Polytechnic College 2015
#
#  ### ● Matrix Rise & Shine Public School 2012
#
#
#
#  ## 🛠️ Skills
#
#  ### ● Git
#  ### ● GIT HUB
#  ### ● MarkDown
#  ### ● VS Code
