# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import numpy as np

# %%
# %pip  install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
xpoint = np.array([0,6])
ypoint = np.array([0,250])

plt.plot(xpoint, ypoint)
plt.show()

# %%
xpoint = np.array([5,9])
ypoint = np.array([0,20])

plt.plot(xpoint, ypoint)
plt.show()

# %%
xpoint = np.array([1,8])
ypoint = np.array([0,10])

plt.plot(xpoint, ypoint ,'o')
plt.show()

# %%
xpoint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint)
plt.show()

# %% [markdown]
# # MArker

# %%
ypoint = np.array([3,8,1,10])
plt.plot(ypoint , marker = 'o')
plt.show()

# %%
xpoint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , marker = 'p')
plt.show()

# %%
xpoint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , marker = 'h')
plt.show()

# %%
xpoint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , marker = 'd')
plt.show()

# %%
xpoint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , marker = 'x')
plt.show()

# %%
xpoint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , marker = '+')
plt.show()

# %%
xpoint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , marker = '^')
plt.show()

# %%
point = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , linestyle= 'dotted')
plt.show()

# %%
oint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , linestyle= 'dashed')
plt.show()

# %%
oint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , linestyle= ':')
plt.show()

# %% [markdown]
# # style OR

# %% [markdown]
# none 'or

# %% [markdown]
# # Color

# %%
oint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , color= 'y')
plt.show()

# %%
oint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , color= 'r')
plt.show()

# %%
oint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint, ypoint , linewidth= '20.0')
plt.show()

# %%
xpoint = np.array([1,2,6,8])
ypoint = np.array([3,8,1,10])

plt.plot(xpoint)
plt.plot (ypoint )
plt.show()

# %%
X1= ([1,2,6,8])
y1=([3,8,1,10])
x2=([3,8,1,10])
y2=([3,8,1,10])

plt.plot(X1,y1,x2,y2)
plt.show()

# %% [markdown]
# # labeling

# %%
X1= ([1,2,6,8])
y1=([3,8,1,10])
x2=([3,8,1,10])
y2=([3,8,1,10])

plt.plot(X1,y1,x2,y2)

plt.xlabel('Al')
plt.ylabel('Ml')

plt.show()

# %%
X1= ([1,2,6,8])
y1=([3,8,1,10])
x2=([3,8,1,10])
y2=([3,8,1,10])

plt.plot(X1,y1,x2,y2)
plt.title('AI & ML')
plt.xlabel('Al')
plt.ylabel('Ml')

plt.show()

# %%
X1= ([1,2,6,8])
y1=([3,8,1,10])
x2=([3,8,1,10])
y2=([3,8,1,10])

font1= {'family':'arial', 'color': 'blue', 'size':28}
font2= {'family':'serif', 'color': 'red', 'size':15}


plt.title("sport watch data",fontdict = font1)
plt.xlabel("Average Pluse",fontdict = font2)
plt.ylabel("Calorie Burnge",fontdict = font2)
plt.plot(X1,y2, x2,y1)
plt.show()

# %%
xpoint = np.array([20,25,27,28,30,31,31,33,35,37])
ypoint = np.array([])
plt.plot(xpoint)
plt.show()

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Cleaned_data.csv') 
print(df)
# Out:
#              Name Designation Gender       Age        Salary
# 0         Mukhtar   Professor      M   37.0000  1.150000e+05
# 1           Azziz     Teacher      M   30.0000  3.500000e+04
# 2          Mohsin    Engineer      M   29.0000  5.000000e+04
# 3   Naveed Fatima     Analyst      F   30.0000  7.000000e+04
# 4           Babar    Engineer      F   25.0000  1.500000e+06
# 5            Aqsa   Scientist      F   22.0000  1.725333e+05
# 6           Rafia     Analyst      F   29.0000  2.000000e+04
# 7           Samra   Scientist      F   26.0000  1.150000e+05
# 8            Eman    Engineer      F   28.0000  3.500000e+04
# 9        Abdullah     Teacher      M   55.0000  1.725333e+05
# 10          Mosib   Professor      M   60.0000  7.000000e+04
# 11          Ahmed    Engineer      M   48.6875  9.000000e+04
# 12          Ahsan     Trainer      M  156.0000  1.100000e+05
# 13          Wajid     Teacher      M   67.0000  2.000000e+03
# ...

# %%
xpoint= df['Salary']
ypoint=df["Age"]
print(ypoint,xpoint)
# Out:
# 0      37.0000
# 1      30.0000
# 2      29.0000
# 3      30.0000
# 4      25.0000
# 5      22.0000
# 6      29.0000
# 7      26.0000
# 8      28.0000
# 9      55.0000
# 10     60.0000
# 11     48.6875
# 12    156.0000
# 13     67.0000
# 14     80.0000
# 15     20.0000
# 16     85.0000
# Name: Age, dtype: float64 0     1.150000e+05
# 1     3.500000e+04
# 2     5.000000e+04
# 3     7.000000e+04
# 4     1.500000e+06
# 5     1.725333e+05
# 6     2.000000e+04
# 7     1.150000e+05
# 8     3.500000e+04
# 9     1.725333e+05
# 10    7.000000e+04
# 11    9.000000e+04
# 12    1.100000e+05
# 13    2.000000e+03
# 14    1.600000e+04
# 15    1.700000e+05
# 16    1.900000e+05
# Name: Salary, dtype: float64

# %%
plt.plot(xpoint, ypoint, linewidth="05")
#plt.subplot(1,2,3)
font1= {'family':'arial', 'color': 'blue', 'size':5}
font2= {'family':'serif', 'color': 'red', 'size':15}
font3= {'family':'serif', 'color': 'red', 'size':15}

plt.title("AI & ML",fontdict = font1)
plt.xlabel("Salary",fontdict = font2)
plt.ylabel("Age",fontdict = font1)
plt.grid(axis= 'x', color= 'blue', linestyle='--', linewidth='2')
plt.grid(axis= 'y', color= 'green', linestyle='--', linewidth='1')
plt.show()

plt.subplot(1,2,4)
X1= ([1,2,6,8])
y1=([3,8,1,10])
x2=([3,8,1,10])
y2=([3,8,1,10])

font1= {'family':'arial', 'color': 'blue', 'size':28}
font2= {'family':'serif', 'color': 'red', 'size':15}
plt.title("sport watch data",fontdict = font1)
plt.xlabel("Average Pluse",fontdict = font2)
plt.ylabel("Calorie Burnge",fontdict = font2)
plt.plot(X1,y2, x2,y1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[144], line 14
#      11 plt.grid(axis= 'y', color= 'green', linestyle='--', linewidth='1')
#      12 plt.show()
# ---> 14 plt.subplot(1,2,4)
#      15 X1= ([1,2,6,8])
#      16 y1=([3,8,1,10])
#
# File c:\Users\YDO hello\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:1544, in subplot(*args, **kwargs)
#    1541 fig = gcf()
#    1543 # First, search for an existing subplot with a matching spec.
# -> 1544 key = SubplotSpec._from_subplot_args(fig, args)
#    1546 for ax in fig.axes:
#    1547     # If we found an Axes at the position, we can reuse it if the user passed no
#    1548     # kwargs or if the Axes class and kwargs are identical.
#    1549     if (ax.get_subplotspec() == key
#    1550         and (kwargs == {}
#    1551              or (ax._projection_init
# ...

# %%
plt.plot(xpoint, ypoint, linewidth="05")
#plt.subplot(1,2,3)
font1= {'family':'arial', 'color': 'blue', 'size':5}
font2= {'family':'serif', 'color': 'red', 'size':15}
font3= {'family':'serif', 'color': 'red', 'size':15}

plt.title("AI & ML",fontdict = font1)
plt.xlabel("Salary",fontdict = font2)
plt.ylabel("Age",fontdict = font1)
plt.grid(axis= 'x', color= 'blue', linestyle='--', linewidth='2')
plt.grid(axis= 'y', color= 'green', linestyle='--', linewidth='1')
plt.show()

# %%
#plt.subplot(1,2,4)
X1= ([1,2,6,8])
y1=([3,8,1,10])
x2=([3,8,1,10])
y2=([3,8,1,10])

font1= {'family':'arial', 'color': 'blue', 'size':28}
font2= {'family':'serif', 'color': 'red', 'size':15}
plt.title("sport watch data",fontdict = font1)
plt.xlabel("Average Pluse",fontdict = font2)
plt.ylabel("Calorie Burnge",fontdict = font2)
plt.subplot(1,2,1)
plt.plot(X1,y1)
plt.subplot(1,2,2)
plt.plot(x2,y2)
plt.show()

# %%
X1= ([3,8,1,10])
y1=([3,8,1,10])
x2=([3,8,1,10])
y2=([3,8,1,10])

font1= {'family':'arial', 'color': 'blue', 'size':28}
font2= {'family':'serif', 'color': 'red', 'size':15}
plt.title("sport watch data",fontdict = font1)
plt.xlabel("Average Pluse",fontdict = font2)
plt.ylabel("Calorie Burnge",fontdict = font2)
plt.subplot(2,3,1)
plt.plot(X1,y1)
plt.subplot(2,3,2)
#plt.figure(figsize = (1,1))
plt.plot(x2,y2)

plt.subplot(2,3,3)
#
plt.plot(X1,y1)
plt.subplot(2,3,4)
#plt.figure(figsize = (5,1))
plt.subplot(2,3,5)
plt.plot(x2,y2)
plt.subplot(2,3,6)
plt.plot(X1,y1)
plt.show()
