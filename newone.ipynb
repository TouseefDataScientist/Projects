# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 1.3 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/8.1 MB 1.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/8.1 MB 1.5 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.1 MB 1.4 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.4 MB/s eta 0:00:05
#    --------- ------------------------------ 1.8/8.1 MB 1.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.1/8.1 MB 1.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.4/8.1 MB 1.4 MB/s eta 0:00:05
#    -------------- ------------------------- 2.9/8.1 MB 1.4 MB/s eta 0:00:04
#    --------------- ------------------------ 3.1/8.1 MB 1.4 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.1 MB 1.4 MB/s eta 0:00:04
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
xpoint= np.array([0,6])
ypoint= np.array([0,250])
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint= np.array([0,250])
ypoint= np.array([10,25])
plt.plot(xpoint,ypoint)
plt.show()

# %%
xpoint= np.array([0,6,4,5])
ypoint= np.array([0,100,150,250])
plt.plot(xpoint,ypoint)
plt.show()

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,marker='o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,marker='*')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,marker='.')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,marker='+')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,marker='d')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,marker='4')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,linestyle='dotted')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,linestyle='dashed')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,linestyle='dashdot')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,color='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,color='pink')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,linewidth='2o.5')
plt.show
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 ypoint= np.array([0,100,150,250])
# ----> 2 plt.plot(ypoint,linewidth='2o.5')
#       3 plt.show
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:3827, in plot(scalex, scaley, data, *args, **kwargs)
#    3819 @_copy_docstring_and_deprecators(Axes.plot)
#    3820 def plot(
#    3821     *args: float | ArrayLike | str,
#    (...)   3825     **kwargs,
#    3826 ) -> list[Line2D]:
# -> 3827     return gca().plot(
#    3828         *args,
#    3829         scalex=scalex,
#    3830         scaley=scaley,
#    3831         **({"data": data} if data is not None else {}),
#    3832         **kwargs,
#    3833     )
#
# ...

# %%
ypoint= np.array([0,100,150,250])
plt.plot(ypoint,linewidth='20.0')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y1= np.array([0,250])
y2= np.array([10,25])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
y1= np.array([0,250])
x1= np.array([0,250])
y2= np.array([10,25])
x2= np.array([0,250])
plt.plot(y1)
plt.plot(x1)
plt.plot(y2)
plt.plot(x2)
plt.show()

# %%
y1= np.array([0,250])
x1= np.array([0,250])
y2= np.array([10,25])
x2= np.array([0,250])
plt.plot(y1)
plt.plot(x1)
plt.plot(y2)
plt.plot(x2)
plt.xlabel('Ai')
plt.ylabel('ML')
plt.show()

# %%
plt.title('Ai&Ml')
plt.ylabel('ML')
plt.xlabel('Ai')
# Out:
# Text(0.5, 0, 'Ai')

# %%
font1={'family':'arial','color':'blue','size':20}
plt.title("sport watch Data",fontdict=font1)
plt.plot(x1)
plt.show()
