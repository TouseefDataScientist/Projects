# %% [markdown]
# <center>
# Name: Fatima Momin  <br>
# Email: fatimamomina423@gmail.com  <br>
# GitHub: https://github.com/dashboard  <br>
# Title: Practice1 for the using panadas libraries <br>
# </center>

# %% [markdown]
# Install Libraries

# %%
# %pip install pandas #install pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#install': Expected package name at the start of dependency specifier
#     #install
#     ^

# %% [markdown]
# Import Panadas

# %%
import pandas as pd #pandas with pd

# %% [markdown]
# Loading DataSet

# %%
pd.read_csv('data.csv')#read the file
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
df=pd.read_csv('data.csv')#store data in dataframe

# %%
df #or print(df)
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
print('This is my dataset')
print(df)
# Out:
# This is my dataset
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %% [markdown]
# Loading XLSX File

# %%
# %pip install pandas openpyxl #to open excel file
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#to': Expected package name at the start of dependency specifier
#     #to
#     ^

# %%
pd.read_excel('data.xlsx')#read the file
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
df=pd.read_excel('data.xlsx')#store in df

# %%
df #print df
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
df.info()#information of data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         17 non-null     object
#  1   Designation  17 non-null     object
#  2   Gender       17 non-null     object
#  3   Age          16 non-null     float64
#  4   Salary       15 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 812.0+ bytes

# %%
df.head()# by default top 5 row
# Out:
#             Name Designation Gender   Age     Salary
# 0        Mukhtar   Professor      M  37.0   115000.0
# 1          Azziz     Teacher      M  30.0    35000.0
# 2         Mohsin    Engineer      M  29.0    50000.0
# 3  Naveed Fatima     Analyst      F  30.0    70000.0
# 4          Babar    Engineer      F  25.0  1500000.0

# %%
df.head(10)# print top 10 row
# Out:
#             Name Designation Gender   Age     Salary
# 0        Mukhtar   Professor      M  37.0   115000.0
# 1          Azziz     Teacher      M  30.0    35000.0
# 2         Mohsin    Engineer      M  29.0    50000.0
# 3  Naveed Fatima     Analyst      F  30.0    70000.0
# 4          Babar    Engineer      F  25.0  1500000.0
# 5           Aqsa   Scientist      F  22.0        NaN
# 6          Rafia     Analyst      F  29.0    20000.0
# 7          Samra   Scientist      F  26.0   115000.0
# 8           Eman    Engineer      F  28.0    35000.0
# 9       Abdullah     Teacher      M  55.0        NaN

# %%
df.tail()# by default bottom 5 row
# Out:
#       Name Designation Gender    Age    Salary
# 12   Ahsan     trainer      M  156.0  110000.0
# 13   Wajid     teacher      M   67.0    2000.0
# 14   Naeem     trainer      M   80.0   16000.0
# 15  Qaisar   professor      M   20.0  170000.0
# 16   Wajid    Engineer      M   85.0  190000.0

# %%
df.tail(2)# botton 2 row
# Out:
#       Name Designation Gender   Age    Salary
# 15  Qaisar   professor      M  20.0  170000.0
# 16   Wajid    Engineer      M  85.0  190000.0

# %%
df.describe()#describe data
# Out:
#              Age        Salary
# count   16.00000  1.500000e+01
# mean    48.68750  1.725333e+05
# std     35.55975  3.713435e+05
# min     20.00000  2.000000e+03
# 25%     27.50000  3.500000e+04
# 50%     30.00000  7.000000e+04
# 75%     61.75000  1.150000e+05
# max    156.00000  1.500000e+06

# %%
df.loc[8]#for specific row
# Out:
# Name               Eman
# Designation    Engineer
# Gender                F
# Age                28.0
# Salary          35000.0
# Name: 8, dtype: object

# %%
df.loc[8:12]# from 8 to 12 row
# Out:
#         Name Designation Gender    Age    Salary
# 8       Eman    Engineer      F   28.0   35000.0
# 9   Abdullah     Teacher      M   55.0       NaN
# 10     Mosib   professor      M   60.0   70000.0
# 11     Ahmed    engineer      M    NaN   90000.0
# 12     Ahsan     trainer      M  156.0  110000.0

# %%
df.isnull().sum() #print null values all
# Out:
# Name           0
# Designation    0
# Gender         0
# Age            1
# Salary         2
# dtype: int64

# %%
df #check here null values
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         17 non-null     object
#  1   Designation  17 non-null     object
#  2   Gender       17 non-null     object
#  3   Age          16 non-null     float64
#  4   Salary       15 non-null     float64
# dtypes: float64(2), object(3)
# memory usage: 812.0+ bytes

# %%
df['Age']# select age column
# Out:
# 0      37.0
# 1      30.0
# 2      29.0
# 3      30.0
# 4      25.0
# 5      22.0
# 6      29.0
# 7      26.0
# 8      28.0
# 9      55.0
# 10     60.0
# 11      NaN
# 12    156.0
# 13     67.0
# 14     80.0
# 15     20.0
# 16     85.0
# Name: Age, dtype: float64

# %%
df['Salary']# select salary coloumn
# Out:
# 0      115000.0
# 1       35000.0
# 2       50000.0
# 3       70000.0
# 4     1500000.0
# 5           NaN
# 6       20000.0
# 7      115000.0
# 8       35000.0
# 9           NaN
# 10      70000.0
# 11      90000.0
# 12     110000.0
# 13       2000.0
# 14      16000.0
# 15     170000.0
# 16     190000.0
# Name: Salary, dtype: float64

# %%
df['Age'].isnull().sum()# print null value in age column
# Out:
# np.int64(1)

# %%
# %pip install python-docx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from docx import Document
doc = Document("data.docx")
text="\n".join([para.text for para in doc.paragraphs])
print(text)
# Out:
# Fatima Momin
# Word File
# It is the dummy document

# %%
# %pip install PyPDF2 pdfplumber reportlab
# Out:
# ...
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/5.6 MB ? eta -:--:--
#    ----- ---------------------------------- 0.8/5.6 MB 2.0 MB/s eta 0:00:03
#    ------- -------------------------------- 1.0/5.6 MB 2.0 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.6/5.6 MB 2.0 MB/s eta 0:00:02
#    -------------- ------------------------- 2.1/5.6 MB 2.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 2.4/5.6 MB 2.0 MB/s eta 0:00:02
#    -------------------- ------------------- 2.9/5.6 MB 2.0 MB/s eta 0:00:02
#    ---------------------- ----------------- 3.1/5.6 MB 1.9 MB/s eta 0:00:02
#    -------------------------- ------------- 3.7/5.6 MB 1.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 3.9/5.6 MB 1.9 MB/s eta 0:00:01
#    ------------------------------- -------- 4.5/5.6 MB 1.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 5.0/5.6 MB 1.9 MB/s eta 0:00:01
# ...

# %%
import PyPDF2

with open('data.pdf', 'rb') as file:
    reader = PyPDF2.PdfReader(file)
    text = ''
    for page in reader.pages:
        text += page.extract_text() or ""
print(text)
# Out:
# Fatima Momin
# Word File
# It is the dummy document
# PDF FILE

# %%
# %pip install pandas csvkit json5
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 1.9 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 1.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 1.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.6/2.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.2 MB 1.0 MB/s eta 0:00:10
# ...

# %%
pd.read_json('data.json')
# Out:
#      name  age     city
# 0  Fatima   24  Karachi
# 1     Ali   30   Lahore

# %%
df=pd.read_json('data.json')

# %%
df
# Out:
#      name  age     city
# 0  Fatima   24  Karachi
# 1     Ali   30   Lahore

# %%
# %pip install requests
# Out:
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import requests

#link 
url = "https://jsonplaceholder.typicode.com/posts"  # Example API

# Fetch data from URL
response = requests.get(url)

import json

# Convert DataFrame to JSON and back to remove escape sequences
clean_text = df.to_json(orient="records", force_ascii=False, indent=4)
print(clean_text)
# Out:
# [
#     {
#         "userId":1,
#         "id":1,
#         "title":"sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#         "body":"quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
#     },
#     {
#         "userId":1,
#         "id":2,
#         "title":"qui est esse",
#         "body":"est rerum tempore vitae\nsequi sint nihil reprehenderit dolor beatae ea dolores neque\nfugiat blanditiis voluptate porro vel nihil molestiae ut reiciendis\nqui aperiam non debitis possimus qui neque nisi nulla"
#     },
#     {
#         "userId":1,
#         "id":3,
#         "title":"ea molestias quasi exercitationem repellat qui ipsa sit aut",
#         "body":"et iusto sed quo iure\nvoluptatem occaecati omnis eligendi aut ad\nvoluptatem doloribus vel accusantium quis pariatur\nmolestiae porro eius odio et labore et velit aut"
#     },
#     {
# ...

# %%
# %pip install lxml html5lib beautifulsoup4
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from bs4 import BeautifulSoup

with open("data.html", "r", encoding="utf-8") as f:
    soup = BeautifulSoup(f, "html.parser")

tables = soup.find_all("table")
print(f"Found {len(tables)} tables.")
# Out:
# Found 1 tables.

# %%
# %pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# #Sql file database
# import sqlite3
# conn = sqlite3.connect("FATIMA.db")
# cursor=conn.cursor()
# cursor.execute("SELECT* FROM sqlite_master WHERE type='table';")
# tables=cursor.fetchall()
# print("Tables",tables)
# cursor.execute("SELECT * FROM customers LIMIT 5;")
# customers=cursor.fetchall()
# for customer in customers:
#     print(customer)

# conn.close()

# %%
import sqlite3

# Connect to the database
conn = sqlite3.connect("data.db")
cursor = conn.cursor()

# Create table if it doesn't exist
cursor.execute("""
    CREATE TABLE IF NOT EXISTS customers (
        id INTEGER PRIMARY KEY,
        name TEXT NOT NULL,
        email TEXT NOT NULL
    )
""")

# Insert sample data
cursor.executemany("INSERT INTO customers (name, email) VALUES (?, ?)", [
    ("Fatima", "fatima@example.com"),
    ("Ali", "ali@example.com"),
    ("Rehman", "rehman@example.com")
])

# Commit changes and close connection
conn.commit()
conn.close()

print("Table 'customers' created and sample data inserted!")

import sqlite3

# Connect to the database
conn = sqlite3.connect("data.db")
cursor = conn.cursor()

# Check existing tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Tables in database:", tables)

# Close connection
conn.close()
# Out:
# Table 'customers' created and sample data inserted!
# Tables in database: [('customers',)]
