# %% [markdown]
# <div class=one>
#
# Name: Fatima Momin  <br>
# Email: fatimamomina423@gmail.com  <br>
# GitHub: https://github.com/dashboard  <br>
# Title:  Task of Data Analysis and Data Cleaning <br>
#
# </div>
#
# <style>
# .one {
#     color: red;
#     text-align:center;
# }
# </style>

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **Checking Missing Values**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **Remove Null Values**

# %%
AgeMedian=df['Age'].median()
df['Age'].fillna(AgeMedian, inplace=True)
df['Age'].isnull().sum()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14288\3172655279.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(AgeMedian, inplace=True)
# np.int64(0)

# %%
CabinCount=df['Cabin'].count()
df['Cabin'].fillna(CabinCount, inplace = True)
df['Cabin'].isnull().sum()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14288\1376963932.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin'].fillna(CabinCount, inplace = True)
# np.int64(0)

# %%
EmbarkedCount=df['Embarked'].count()
df['Embarked'].fillna(EmbarkedCount, inplace = True)
df['Embarked'].isnull().sum()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14288\2711600417.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(EmbarkedCount, inplace = True)
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df=df.drop(columns=['PassengerId','Pclass','SibSp','Cabin','Parch','Cabin'])
df
# Out:
#      Survived                                               Name     Sex  \
# 0           0                            Braund, Mr. Owen Harris    male
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2           1                             Heikkinen, Miss. Laina  female
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0                           Allen, Mr. William Henry    male
# ..        ...                                                ...     ...
# 886         0                              Montvila, Rev. Juozas    male
# 887         1                       Graham, Miss. Margaret Edith  female
# 888         0           Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1                              Behr, Mr. Karl Howell    male
# 890         0                                Dooley, Mr. Patrick    male
#
#       Age            Ticket     Fare Embarked
# ...

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age']=df['Age'].apply(lambda x: x if x < 100 else AgeMedian)
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df
# Out:
#      Survived                                               Name     Sex  \
# 0           0                            Braund, Mr. Owen Harris    male
# 1           1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2           1                             Heikkinen, Miss. Laina  female
# 3           1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0                           Allen, Mr. William Henry    male
# ..        ...                                                ...     ...
# 886         0                              Montvila, Rev. Juozas    male
# 887         1                       Graham, Miss. Margaret Edith  female
# 888         0           Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1                              Behr, Mr. Karl Howell    male
# 890         0                                Dooley, Mr. Patrick    male
#
#       Age            Ticket     Fare Embarked
# ...

# %%
FareMedian=df['Fare'].median()
df['Fare'].fillna(FareMedian, inplace=True)
df['Fare'].isnull().sum()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14288\1639950143.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fare'].fillna(FareMedian, inplace=True)
# np.int64(0)

# %%
df['Fare']=df['Fare'].apply(lambda x: x if x < 30.0000 else FareMedian)

# %%
df['Fare']=df['Fare'].apply(lambda x: x if x > 8.05 else FareMedian)

# %%
df['Fare']
# Out:
# 0      14.4542
# 1      14.4542
# 2      14.4542
# 3      14.4542
# 4      14.4542
#         ...
# 886    13.0000
# 887    14.4542
# 888    23.4500
# 889    14.4542
# 890    14.4542
# Name: Fare, Length: 891, dtype: float64

# %%
df['Age']=df['Age'].apply(lambda x: x if x > 18 else AgeMedian)
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Sex']=df['Sex'].str.title()
df['Sex']
# Out:
# 0        Male
# 1      Female
# 2      Female
# 3      Female
# 4        Male
#         ...
# 886      Male
# 887    Female
# 888    Female
# 889      Male
# 890      Male
# Name: Sex, Length: 891, dtype: object

# %%
df['Sex'] = df['Sex'].replace({'Female': 'F', 'Male': 'M'})
df['Sex']
# Out:
# 0      M
# 1      F
# 2      F
# 3      F
# 4      M
#       ..
# 886    M
# 887    F
# 888    F
# 889    M
# 890    M
# Name: Sex, Length: 891, dtype: object

# %%
df['Survived'] = df['Survived'].replace({0: 'Death', 1: 'Live'})
df['Survived']
# Out:
# 0      Death
# 1       Live
# 2       Live
# 3       Live
# 4      Death
#        ...
# 886    Death
# 887     Live
# 888    Death
# 889     Live
# 890    Death
# Name: Survived, Length: 891, dtype: object

# %%
df['Embarked'] = df['Embarked'].replace({'S': 'Southampton', 'C': 'Cherbourg','Q':'Queenstown'})
df['Embarked']
# Out:
# 0      Southampton
# 1        Cherbourg
# 2      Southampton
# 3      Southampton
# 4      Southampton
#           ...
# 886    Southampton
# 887    Southampton
# 888    Southampton
# 889      Cherbourg
# 890     Queenstown
# Name: Embarked, Length: 891, dtype: object

# %%
df
# Out:
#     Survived                                               Name Sex   Age  \
# 0      Death                            Braund, Mr. Owen Harris   M  22.0
# 1       Live  Cumings, Mrs. John Bradley (Florence Briggs Th...   F  38.0
# 2       Live                             Heikkinen, Miss. Laina   F  26.0
# 3       Live       Futrelle, Mrs. Jacques Heath (Lily May Peel)   F  35.0
# 4      Death                           Allen, Mr. William Henry   M  35.0
# ..       ...                                                ...  ..   ...
# 886    Death                              Montvila, Rev. Juozas   M  27.0
# 887     Live                       Graham, Miss. Margaret Edith   F  19.0
# 888    Death           Johnston, Miss. Catherine Helen "Carrie"   F  28.0
# 889     Live                              Behr, Mr. Karl Howell   M  26.0
# 890    Death                                Dooley, Mr. Patrick   M  32.0
#
#                Ticket     Fare     Embarked
# ...

# %%
FareGender=df.groupby('Sex')['Fare'].mean()
FareGender
# Out:
# Sex
# F    16.061960
# M    15.493897
# Name: Fare, dtype: float64

# %%
HighFare=df[df['Fare'] > 16.000000]
HighFare
# Out:
#     Survived                                               Name Sex   Age  \
# 7      Death                     Palsson, Master. Gosta Leonard   M  28.0
# 10      Live                    Sandstrom, Miss. Marguerite Rut   F  28.0
# 11      Live                           Bonnell, Miss. Elizabeth   F  58.0
# 16     Death                               Rice, Master. Eugene   M  28.0
# 18     Death  Vander Planke, Mrs. Julius (Emelia Maria Vande...   F  31.0
# ..       ...                                                ...  ..   ...
# 862     Live  Swift, Mrs. Frederick Joel (Margaret Welles Ba...   F  48.0
# 874     Live              Abelson, Mrs. Samuel (Hannah Wizosky)   F  28.0
# 880     Live       Shelley, Mrs. William (Imanita Parrish Hall)   F  25.0
# 885    Death               Rice, Mrs. William (Margaret Norton)   F  39.0
# 888    Death           Johnston, Miss. Catherine Helen "Carrie"   F  28.0
#
#          Ticket     Fare     Embarked
# 7        349909  21.0750  Southampton
# ...

# %%
df.to_csv('Cleaned_Titanic.csv',index=False)

# %%
df["Age"] = df["Age"].astype(int)
df['Fare']=df['Fare'].astype(float)
df
# Out:
#     Survived                                               Name Sex  Age  \
# 0      Death                            Braund, Mr. Owen Harris   M   22
# 1       Live  Cumings, Mrs. John Bradley (Florence Briggs Th...   F   38
# 2       Live                             Heikkinen, Miss. Laina   F   26
# 3       Live       Futrelle, Mrs. Jacques Heath (Lily May Peel)   F   35
# 4      Death                           Allen, Mr. William Henry   M   35
# ..       ...                                                ...  ..  ...
# 886    Death                              Montvila, Rev. Juozas   M   27
# 887     Live                       Graham, Miss. Margaret Edith   F   19
# 888    Death           Johnston, Miss. Catherine Helen "Carrie"   F   28
# 889     Live                              Behr, Mr. Karl Howell   M   26
# 890    Death                                Dooley, Mr. Patrick   M   32
#
#                Ticket     Fare     Embarked
# 0           A/5 21171  14.4542  Southampton
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    object
#  1   Name      891 non-null    object
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    int64
#  4   Ticket    891 non-null    object
#  5   Fare      891 non-null    float64
#  6   Embarked  891 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 48.9+ KB

# %%
df.describe()
# Out:
#               Age        Fare
# count  891.000000  891.000000
# mean    32.048260   15.694090
# std     10.083189    4.536173
# min     19.000000    8.112500
# 25%     28.000000   14.454200
# 50%     28.000000   14.454200
# 75%     35.000000   14.454200
# max     80.000000   29.700000

# %%
df
# Out:
#     Survived                                               Name Sex  Age  \
# 0      Death                            Braund, Mr. Owen Harris   M   22
# 1       Live  Cumings, Mrs. John Bradley (Florence Briggs Th...   F   38
# 2       Live                             Heikkinen, Miss. Laina   F   26
# 3       Live       Futrelle, Mrs. Jacques Heath (Lily May Peel)   F   35
# 4      Death                           Allen, Mr. William Henry   M   35
# ..       ...                                                ...  ..  ...
# 886    Death                              Montvila, Rev. Juozas   M   27
# 887     Live                       Graham, Miss. Margaret Edith   F   19
# 888    Death           Johnston, Miss. Catherine Helen "Carrie"   F   28
# 889     Live                              Behr, Mr. Karl Howell   M   26
# 890    Death                                Dooley, Mr. Patrick   M   32
#
#                Ticket     Fare     Embarked
# 0           A/5 21171  14.4542  Southampton
# ...
