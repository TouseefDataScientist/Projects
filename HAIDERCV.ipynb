# %% [markdown]
# # **HAIR NASIR**
#
# ## 📄 **Personal Information**
# - **Email:** [haidernasir57@GMmail.com]
# - **Phone:** [+92-3065332589]
# - **LinkedIn:** [www.linkedin.com/in/haider-nasir-9701171a9]
# - **GitHub:** [https://github.com/haidernasirr]
# - **Location:** [Islamabadd,Pakistan]
#
# ---
#
# ## 🧑‍💼 **Professional Summary**
#
# Enthusiastic and detail-oriented **Software Engineer** with a solid foundation in **C++**, **Java**, **MERN Stack**, **Git**, and **GitHub**. Passionate about developing efficient and scalable software solutions. Strong collaborative and communication skills, with a drive to continuously improve and learn new technologies.
#
# ---
#
# ## 🎓 **Education**
#
# **Bachelor of Science in Information Technology (BSIT)**
# **Quaid-e-Azam University, Islamabad**
# *September 2020 – June 2024*
#
# ---
#
# ## 💻 **Technical Skills**
#
# - **Languages:** C++, Java, JavaScript, HTML, CSS
# - **Frameworks & Libraries:** React.js, Node.js, Express.js
# - **Databases:** MongoDB
# - **Version Control:** Git, GitHub
# - **Other Tools & Technologies:** Markdown, REST APIs, VS Code, Postman
# - **Soft Skills:** Problem Solving, Team Collaboration, Critical Thinking
#
# ---
#
# ## 🛠️ **Projects**
#
# ### **1. Task Manager App (MERN Stack)**
# - Developed a full-stack task management web application.
# - Users can create, update, and delete tasks.
# - Implemented authentication using JWT and bcrypt.
# - **Technologies:** React.js, Node.js, Express.js, MongoDB.
#
# ### **2. Library Management System (C++)**
# - Designed and implemented a console-based library system in C++.
# - Allowed adding, deleting, and issuing books to members.
# - Applied OOP concepts and file handling for data persistence.
#
# ### **3. E-Commerce Website (HTML, CSS, JavaScript)**
# - Built a responsive e-commerce front-end for a dummy store.
# - Implemented search and filter functionality for product listings.
# - Focused on clean, responsive UI and user-friendly navigation.
#
# ### **4. Personal Portfolio Website (React.js & CSS)**
# - Created a personal portfolio to showcase projects and skills.
# - Implemented responsive design with React components.
# - Hosted the portfolio on GitHub Pages.
#
# ---
#
# ## 🏢 **Experience**
#
# ### **Software Engineering Intern**
# **GAO Tek Inc.** *(Remote)*
# *January 2025 – Present*
# - Contributed to software development and testing projects.
# - Collaborated on GitHub for version control and code reviews.
# - Published technical blogs related to GAO products and services.
# - Developed communication skills in a remote, international work environment.
#
# ### **Freelance Web Developer**
# *2023 – 2024*
# - Built custom websites for small businesses and personal brands.
# - Designed user-friendly layouts and responsive interfaces.
# - Deployed projects using GitHub Pages and basic hosting services.
# - Managed projects independently, from requirements gathering to final deployment.
#
# ---
#
# ## 📜 **Certifications**
#
# - **Introduction to Git and GitHub** – Coursera
# - **Responsive Web Design** – freeCodeCamp
# - **C++ Programming Fundamentals** – Udemy
#
# ---
#
# ## 🌐 **Languages**
#
# - English: Fluent
# - Urdu: Native
#
# ---
#
# ## 🎯 **Hobbies & Interests**
#
# - Open-source contributions
# - Competitive programming
# - Blogging about tech
# - Football and fitness
#
# ---
