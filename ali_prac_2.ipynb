# %% [markdown]
# <div class="sty">
# Name:Mohammed Ali <br>
# Github:https://github.com/Muhammad5Ali <br>
# Email:"rajaaliking789@gmail.com" <br>
# Title:"Practice" <br>
# </div>
#
# <style>
# .sty{
# color:skyblue;
# text-align:center;
# }
# </style>

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# #Loading the csv files

# %%
df=pd.read_csv('data.csv')

# %%
df
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
df.head()
# Out:
#             Name Designation Gender   Age     Salary
# 0        Mukhtar   Professor      M  37.0   115000.0
# 1          Azziz     Teacher      M  30.0    35000.0
# 2         Mohsin    Engineer      M  29.0    50000.0
# 3  Naveed Fatima     Analyst      F  30.0    70000.0
# 4          Babar    Engineer      F  25.0  1500000.0

# %%
df.tail()
# Out:
#       Name Designation Gender    Age    Salary
# 12   Ahsan     trainer      M  156.0  110000.0
# 13   Wajid     teacher      M   67.0    2000.0
# 14   Naeem     trainer      M   80.0   16000.0
# 15  Qaisar   professor      M   20.0  170000.0
# 16   Wajid    Engineer      M   85.0  190000.0

# %%
df.loc[3:5]
# Out:
#             Name Designation Gender   Age     Salary
# 3  Naveed Fatima     Analyst      F  30.0    70000.0
# 4          Babar    Engineer      F  25.0  1500000.0
# 5           Aqsa   Scientist      F  22.0        NaN

# %%
df.describe()
# Out:
#              Age        Salary
# count   16.00000  1.500000e+01
# mean    48.68750  1.725333e+05
# std     35.55975  3.713435e+05
# min     20.00000  2.000000e+03
# 25%     27.50000  3.500000e+04
# 50%     30.00000  7.000000e+04
# 75%     61.75000  1.150000e+05
# max    156.00000  1.500000e+06

# %%
df.shape
# Out:
# (17, 5)

# %%
df['Age']
# Out:
# 0      37.0
# 1      30.0
# 2      29.0
# 3      30.0
# 4      25.0
# 5      22.0
# 6      29.0
# 7      26.0
# 8      28.0
# 9      55.0
# 10     60.0
# 11      NaN
# 12    156.0
# 13     67.0
# 14     80.0
# 15     20.0
# 16     85.0
# Name: Age, dtype: float64

# %%
df.loc[3]
# Out:
# Name           Naveed Fatima
# Designation          Analyst
# Gender                     F
# Age                     30.0
# Salary               70000.0
# Name: 3, dtype: object

# %%
df['Age']
# Out:
# 0      37.0
# 1      30.0
# 2      29.0
# 3      30.0
# 4      25.0
# 5      22.0
# 6      29.0
# 7      26.0
# 8      28.0
# 9      55.0
# 10     60.0
# 11      NaN
# 12    156.0
# 13     67.0
# 14     80.0
# 15     20.0
# 16     85.0
# Name: Age, dtype: float64

# %%
#Selecting name and designation of 4 and 5 row
df1=df[['Name',"Designation"]]
df1
# Out:
#              Name Designation
# 0         Mukhtar   Professor
# 1           Azziz     Teacher
# 2          Mohsin    Engineer
# 3   Naveed Fatima     Analyst
# 4           Babar    Engineer
# 5            Aqsa   Scientist
# 6           Rafia     Analyst
# 7           Samra   Scientist
# 8            Eman    Engineer
# 9        Abdullah     Teacher
# 10          Mosib   professor
# 11          Ahmed    engineer
# 12          Ahsan     trainer
# 13          Wajid     teacher
# 14          Naeem     trainer
# 15         Qaisar   professor
# 16          Wajid    Engineer

# %%
#Selecting four columns
df4=df[['Name','Designation','Salary','Age']]
df4
# Out:
#              Name Designation     Salary    Age
# 0         Mukhtar   Professor   115000.0   37.0
# 1           Azziz     Teacher    35000.0   30.0
# 2          Mohsin    Engineer    50000.0   29.0
# 3   Naveed Fatima     Analyst    70000.0   30.0
# 4           Babar    Engineer  1500000.0   25.0
# 5            Aqsa   Scientist        NaN   22.0
# 6           Rafia     Analyst    20000.0   29.0
# 7           Samra   Scientist   115000.0   26.0
# 8            Eman    Engineer    35000.0   28.0
# 9        Abdullah     Teacher        NaN   55.0
# 10          Mosib   professor    70000.0   60.0
# 11          Ahmed    engineer    90000.0    NaN
# 12          Ahsan     trainer   110000.0  156.0
# 13          Wajid     teacher     2000.0   67.0
# 14          Naeem     trainer    16000.0   80.0
# 15         Qaisar   professor   170000.0   20.0
# 16          Wajid    Engineer   190000.0   85.0

# %%
#select specific columns for specific row
#one method
select_rows_columns=df.loc[4:5 ,["Name","Designation"]]
lo=select_rows_columns
lo
# Out:
#     Name Designation
# 4  Babar    Engineer
# 5   Aqsa   Scientist

# %%
#Selecting only the row 1 and printing its name and designation
selected_row=df.loc[1,["Name","Salary"]]
selected_row
# Out:
# Name        Azziz
# Salary    35000.0
# Name: 1, dtype: object

# %%
nullValue=df.isnull().sum()

# %%
nullValue
# Out:
# Name           0
# Designation    0
# Gender         0
# Age            1
# Salary         2
# dtype: int64

# %%
df
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
#To drop the value of null of index 5 of aqsa
drop5=df.drop(index=5)
drop5
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# 16          Wajid    Engineer      M   85.0   190000.0

# %%
df
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
dropBoth=df.drop(index=[5,9])
dropBoth
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# 16          Wajid    Engineer      M   85.0   190000.0

# %%
#For dropping the column
col=df.drop(columns='Gender')
col
# Out:
#              Name Designation    Age     Salary
# 0         Mukhtar   Professor   37.0   115000.0
# 1           Azziz     Teacher   30.0    35000.0
# 2          Mohsin    Engineer   29.0    50000.0
# 3   Naveed Fatima     Analyst   30.0    70000.0
# 4           Babar    Engineer   25.0  1500000.0
# 5            Aqsa   Scientist   22.0        NaN
# 6           Rafia     Analyst   29.0    20000.0
# 7           Samra   Scientist   26.0   115000.0
# 8            Eman    Engineer   28.0    35000.0
# 9        Abdullah     Teacher   55.0        NaN
# 10          Mosib   professor   60.0    70000.0
# 11          Ahmed    engineer    NaN    90000.0
# 12          Ahsan     trainer  156.0   110000.0
# 13          Wajid     teacher   67.0     2000.0
# 14          Naeem     trainer   80.0    16000.0
# 15         Qaisar   professor   20.0   170000.0
# 16          Wajid    Engineer   85.0   190000.0

# %%
#For dropping the multiple colums
multiCol=df.drop(columns=['Age','Salary'])
multiCol
# Out:
#              Name Designation Gender
# 0         Mukhtar   Professor      M
# 1           Azziz     Teacher      M
# 2          Mohsin    Engineer      M
# 3   Naveed Fatima     Analyst      F
# 4           Babar    Engineer      F
# 5            Aqsa   Scientist      F
# 6           Rafia     Analyst      F
# 7           Samra   Scientist      F
# 8            Eman    Engineer      F
# 9        Abdullah     Teacher      M
# 10          Mosib   professor      M
# 11          Ahmed    engineer      M
# 12          Ahsan     trainer      M
# 13          Wajid     teacher      M
# 14          Naeem     trainer      M
# 15         Qaisar   professor      M
# 16          Wajid    Engineer      M

# %%
#Dealing with the Null Values
df.isnull().sum()
# Out:
# Name           0
# Designation    0
# Gender         0
# Age            1
# Salary         2
# dtype: int64

# %%
#Now particularly checking for the age
df['Age'].isnull().sum()
##Two methods are there first one is to drop and second one is to replace by the median
# Out:
# np.int64(1)

# %%
dfDeal=df['Age'].fillna(df['Age'].median())
df
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
dfDeal
# Out:
# 0      37.0
# 1      30.0
# 2      29.0
# 3      30.0
# 4      25.0
# 5      22.0
# 6      29.0
# 7      26.0
# 8      28.0
# 9      55.0
# 10     60.0
# 11     30.0
# 12    156.0
# 13     67.0
# 14     80.0
# 15     20.0
# 16     85.0
# Name: Age, dtype: float64

# %%
dfDeal.isnull().sum()
#Now zero null value
# Out:
# np.int64(0)

# %%
#now dealing with the null value of the Salary
dfSal=df['Salary'].isnull().sum()
dfSal
# Out:
# np.int64(2)

# %%
#Here we use the median values to fill up the null/empty values 1:METHOD
dfRem=df['Salary'].fillna(df['Salary'].median())
dfRem
# Out:
# 0      115000.0
# 1       35000.0
# 2       50000.0
# 3       70000.0
# 4     1500000.0
# 5       70000.0
# 6       20000.0
# 7      115000.0
# 8       35000.0
# 9       70000.0
# 10      70000.0
# 11      90000.0
# 12     110000.0
# 13       2000.0
# 14      16000.0
# 15     170000.0
# 16     190000.0
# Name: Salary, dtype: float64

# %%
dfRem.isnull().sum()
# Out:
# np.int64(0)

# %%
#2: WAY HERE IS TO DROP THE VALUES THAT ARE NULL BUT IT WILL ALTERNATIVELY REMOVE THE INDEX
sec_way=df.dropna(subset=['Salary'])
sec_way
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# 16          Wajid    Engineer      M   85.0   190000.0

# %%
#Conditional-Based
high_sal=df[df['Salary']>100000]
high_sal
# Out:
#        Name Designation Gender    Age     Salary
# 0   Mukhtar   Professor      M   37.0   115000.0
# 4     Babar    Engineer      F   25.0  1500000.0
# 7     Samra   Scientist      F   26.0   115000.0
# 12    Ahsan     trainer      M  156.0   110000.0
# 15   Qaisar   professor      M   20.0   170000.0
# 16    Wajid    Engineer      M   85.0   190000.0

# %%
#Sorting the data
sort=df.sort_values(by='Age',ascending=True)
sort
# Out:
#              Name Designation Gender    Age     Salary
# 15         Qaisar   professor      M   20.0   170000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 4           Babar    Engineer      F   25.0  1500000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 6           Rafia     Analyst      F   29.0    20000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 0         Mukhtar   Professor      M   37.0   115000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 16          Wajid    Engineer      M   85.0   190000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# ...

# %%
#Sorting in the descending order
sort2=df.sort_values(by='Salary',ascending=False)
sort2
# Out:
#              Name Designation Gender    Age     Salary
# 4           Babar    Engineer      F   25.0  1500000.0
# 16          Wajid    Engineer      M   85.0   190000.0
# 15         Qaisar   professor      M   20.0   170000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 0         Mukhtar   Professor      M   37.0   115000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 10          Mosib   professor      M   60.0    70000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 6           Rafia     Analyst      F   29.0    20000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# ...

# %%
#Grouping on based of the particular field
group=df.groupby('Designation')['Salary'].mean()
group
# Out:
# Designation
# Analyst       45000.0
# Engineer     443750.0
# Professor    115000.0
# Scientist    115000.0
# Teacher       35000.0
# engineer      90000.0
# professor    120000.0
# teacher        2000.0
# trainer       63000.0
# Name: Salary, dtype: float64

# %%
#Adding a new column
df['ExperienceLev']=['Senior' if age>35 else 'Junior' for age in df['Age']]
df['ExperienceLev']
df.head()
# Out:
#             Name Designation Gender   Age     Salary ExperienceLev
# 0        Mukhtar   Professor      M  37.0   115000.0        Senior
# 1          Azziz     Teacher      M  30.0    35000.0        Junior
# 2         Mohsin    Engineer      M  29.0    50000.0        Junior
# 3  Naveed Fatima     Analyst      F  30.0    70000.0        Junior
# 4          Babar    Engineer      F  25.0  1500000.0        Junior

# %% [markdown]
# #LOADING THE .XLSX FILES

# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
excel=pd.read_excel('data.xlsx')

# %%
excel
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
excel.head()
# Out:
#             Name Designation Gender   Age     Salary
# 0        Mukhtar   Professor      M  37.0   115000.0
# 1          Azziz     Teacher      M  30.0    35000.0
# 2         Mohsin    Engineer      M  29.0    50000.0
# 3  Naveed Fatima     Analyst      F  30.0    70000.0
# 4          Babar    Engineer      F  25.0  1500000.0

# %%
df.tail()
# Out:
#       Name Designation Gender    Age    Salary ExperienceLev
# 12   Ahsan     trainer      M  156.0  110000.0        Senior
# 13   Wajid     teacher      M   67.0    2000.0        Senior
# 14   Naeem     trainer      M   80.0   16000.0        Senior
# 15  Qaisar   professor      M   20.0  170000.0        Junior
# 16   Wajid    Engineer      M   85.0  190000.0        Senior

# %%
excel.tail()
# Out:
#       Name Designation Gender    Age    Salary
# 12   Ahsan     trainer      M  156.0  110000.0
# 13   Wajid     teacher      M   67.0    2000.0
# 14   Naeem     trainer      M   80.0   16000.0
# 15  Qaisar   professor      M   20.0  170000.0
# 16   Wajid    Engineer      M   85.0  190000.0

# %%
excel.describe()
# Out:
#              Age        Salary
# count   16.00000  1.500000e+01
# mean    48.68750  1.725333e+05
# std     35.55975  3.713435e+05
# min     20.00000  2.000000e+03
# 25%     27.50000  3.500000e+04
# 50%     30.00000  7.000000e+04
# 75%     61.75000  1.150000e+05
# max    156.00000  1.500000e+06

# %%
excel.shape
# Out:
# (17, 5)

# %%
excel
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
#Selecting the row
excel.loc[3]
# Out:
# Name           Naveed Fatima
# Designation          Analyst
# Gender                     F
# Age                     30.0
# Salary               70000.0
# Name: 3, dtype: object

# %%
#Selecting column
excel['Age']
# Out:
# 0      37.0
# 1      30.0
# 2      29.0
# 3      30.0
# 4      25.0
# 5      22.0
# 6      29.0
# 7      26.0
# 8      28.0
# 9      55.0
# 10     60.0
# 11      NaN
# 12    156.0
# 13     67.0
# 14     80.0
# 15     20.0
# 16     85.0
# Name: Age, dtype: float64

# %%
#Selecting multiple rows
excel.loc[2:5]
# Out:
#             Name Designation Gender   Age     Salary
# 2         Mohsin    Engineer      M  29.0    50000.0
# 3  Naveed Fatima     Analyst      F  30.0    70000.0
# 4          Babar    Engineer      F  25.0  1500000.0
# 5           Aqsa   Scientist      F  22.0        NaN

# %%
excel[['Age','Salary']]
# Out:
#       Age     Salary
# 0    37.0   115000.0
# 1    30.0    35000.0
# 2    29.0    50000.0
# 3    30.0    70000.0
# 4    25.0  1500000.0
# 5    22.0        NaN
# 6    29.0    20000.0
# 7    26.0   115000.0
# 8    28.0    35000.0
# 9    55.0        NaN
# 10   60.0    70000.0
# 11    NaN    90000.0
# 12  156.0   110000.0
# 13   67.0     2000.0
# 14   80.0    16000.0
# 15   20.0   170000.0
# 16   85.0   190000.0

# %%
#Selecting columns of the specific rows
excel.loc[4:6,['Age','Gender']]
# Out:
#     Age Gender
# 4  25.0      F
# 5  22.0      F
# 6  29.0      F

# %%
#Now deal with the null values
excel.isnull().sum()
# Out:
# Name           0
# Designation    0
# Gender         0
# Age            1
# Salary         2
# dtype: int64

# %%
excel['Age'].isnull().sum()
# Out:
# np.int64(1)

# %%
excel
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
dd1=excel.drop(index=5)
dd1
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# 16          Wajid    Engineer      M   85.0   190000.0

# %%
dd2=excel.drop(index=[5,9])
dd2
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# 16          Wajid    Engineer      M   85.0   190000.0

# %%
dc1=excel.drop(columns='Salary')
dc1
# Out:
#              Name Designation Gender    Age
# 0         Mukhtar   Professor      M   37.0
# 1           Azziz     Teacher      M   30.0
# 2          Mohsin    Engineer      M   29.0
# 3   Naveed Fatima     Analyst      F   30.0
# 4           Babar    Engineer      F   25.0
# 5            Aqsa   Scientist      F   22.0
# 6           Rafia     Analyst      F   29.0
# 7           Samra   Scientist      F   26.0
# 8            Eman    Engineer      F   28.0
# 9        Abdullah     Teacher      M   55.0
# 10          Mosib   professor      M   60.0
# 11          Ahmed    engineer      M    NaN
# 12          Ahsan     trainer      M  156.0
# 13          Wajid     teacher      M   67.0
# 14          Naeem     trainer      M   80.0
# 15         Qaisar   professor      M   20.0
# 16          Wajid    Engineer      M   85.0

# %%
dc2=excel.drop(columns=['Age','Salary'])
dc2
# Out:
#              Name Designation Gender
# 0         Mukhtar   Professor      M
# 1           Azziz     Teacher      M
# 2          Mohsin    Engineer      M
# 3   Naveed Fatima     Analyst      F
# 4           Babar    Engineer      F
# 5            Aqsa   Scientist      F
# 6           Rafia     Analyst      F
# 7           Samra   Scientist      F
# 8            Eman    Engineer      F
# 9        Abdullah     Teacher      M
# 10          Mosib   professor      M
# 11          Ahmed    engineer      M
# 12          Ahsan     trainer      M
# 13          Wajid     teacher      M
# 14          Naeem     trainer      M
# 15         Qaisar   professor      M
# 16          Wajid    Engineer      M

# %%
#TWO WAYS OF DEALING WITH THE NULL-VALUES
df.isnull().sum()
# Out:
# Name             0
# Designation      0
# Gender           0
# Age              1
# Salary           2
# ExperienceLev    0
# dtype: int64

# %%
df['Salary'].isnull().sum()
# Out:
# np.int64(2)

# %%
dealing=df['Salary'].fillna(df['Salary'].median())

# %%
dealing
# Out:
# 0      115000.0
# 1       35000.0
# 2       50000.0
# 3       70000.0
# 4     1500000.0
# 5       70000.0
# 6       20000.0
# 7      115000.0
# 8       35000.0
# 9       70000.0
# 10      70000.0
# 11      90000.0
# 12     110000.0
# 13       2000.0
# 14      16000.0
# 15     170000.0
# 16     190000.0
# Name: Salary, dtype: float64

# %%
dealing.isnull().sum()
# Out:
# np.int64(0)

# %%
#We have got the other way in which we particularly  drop the index which  has a null value
sub=excel.dropna(subset='Salary')
sub
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# 16          Wajid    Engineer      M   85.0   190000.0

# %%
#Conditional
con=excel[excel['Age']>30]
con
# Out:
#         Name Designation Gender    Age    Salary
# 0    Mukhtar   Professor      M   37.0  115000.0
# 9   Abdullah     Teacher      M   55.0       NaN
# 10     Mosib   professor      M   60.0   70000.0
# 12     Ahsan     trainer      M  156.0  110000.0
# 13     Wajid     teacher      M   67.0    2000.0
# 14     Naeem     trainer      M   80.0   16000.0
# 16     Wajid    Engineer      M   85.0  190000.0

# %%
#sort
sor=excel.sort_values(by='Salary',ascending=True)
sor
# Out:
#              Name Designation Gender    Age     Salary
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 6           Rafia     Analyst      F   29.0    20000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 0         Mukhtar   Professor      M   37.0   115000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 15         Qaisar   professor      M   20.0   170000.0
# 16          Wajid    Engineer      M   85.0   190000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# ...

# %%
excel.groupby('Gender')['Salary'].mean()
# Out:
# Gender
# F    348000.0
# M     84800.0
# Name: Salary, dtype: float64

# %%
#Adding new colums
excel['Rank']=['High' if salary>20000 else 'Low' for salary in excel['Salary']]
excel['Rank']
excel.head()
# Out:
#             Name Designation Gender   Age     Salary  Rank
# 0        Mukhtar   Professor      M  37.0   115000.0  High
# 1          Azziz     Teacher      M  30.0    35000.0  High
# 2         Mohsin    Engineer      M  29.0    50000.0  High
# 3  Naveed Fatima     Analyst      F  30.0    70000.0  High
# 4          Babar    Engineer      F  25.0  1500000.0  High

# %% [markdown]
# #Loading a docx file

# %%
# %pip install python-docx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from docx import Document
#Loading document
doc=Document("Internship.docx")

#Read and print all content

for para in doc.paragraphs:
    print(para.text)
# Out:
# [Today’s Date]
#
# [Hiring Manager’s Name]
# 123 Company Address
# Company’s City, State, Zip Code
# (xxx) xxx-xxxx
# hiring.manager@gmail.com
#
# Dear [Mr./Ms./Mx.] [Hiring Manager’s Last Name],
#
# I’m writing to you regarding the marketing role that opened up recently. I came across the job description on [Website Name] and was delighted to find that my academic accomplishments meet all of the necessary requirements. I am seeking a challenging but rewarding internship, which is why I was drawn to this exciting opportunity.
# As a junior marketing student at the University of Georgia, I have acquired skills in advertising, PR, product development, and market research. Currently I hold a 3.8 GPA and have been on the Dean’s List every semester. While in the College of Business, I have strategically focused my coursework in the following areas:
# Marketing Analytics
# Marketing Management
# Survey Research
# Strategic Internet Marketing
# Integrated Marketing Communications
# ...
