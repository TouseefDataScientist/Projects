# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Cleaned_titanic.csv')
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
x= df['Age']
y= df['Fare']

# %%
plt.title('Titanic')

plt.xlabel('Age' )
plt.ylabel('Fare')

plt.scatter(x,y, color='red' , label='Age')
plt.scatter(x,y, color='blue' , label='Fare' , alpha=0.5)
plt.legend()
plt.show()

# %%
x= df['Age']
y= df['Fare']
plt.title('Titanic')
plt.xlabel('Age' )
plt.ylabel('Fare')

plt.scatter(x,y, edgecolor='red' , facecolor='green')
#plt.scatter(x,y, color='blue' , label='Fare' , alpha=0.5)
#plt.legend()
plt.show()

# %%
x= df['Age']
y= df['Fare']

plt.title('Titanic')
plt.xlabel('Age' )
plt.ylabel('Fare')

colors= ["red" if age >30 else 'green' for age in x]
plt.scatter(x,y, c=colors)
plt.show()

# %%
x= df['Age']
y= df['Fare']

plt.title('Titanic')
plt.xlabel('Age' )
plt.ylabel('Fare')
colors= ["red" if age <=10 else
         'green' if age <=20 else
         'blue' if age <=30 else
         'black' if age <=40 else
         'pink' if age <=50 else
         'orange' if age <=60 else
         'violet' if age <=70 else
          'gray'for age in x]

plt.scatter(x,y, c=colors , marker='+')
plt.show()
