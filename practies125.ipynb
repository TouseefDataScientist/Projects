# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
xpoints= np.array([0,6])
ypoints= np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints= np.array([0,8])
ypoints= np.array([0,10])
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
xpoints= np.array([1,2,6,8])
ypoints= np.array([3,6,1,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints= np.array([1,2,6,8])

plt.plot(xpoints,marker='o')
plt.show()

# %%
xpoints= np.array([1,2,6,8])

plt.plot(xpoints,marker='*')
plt.show()

# %%
xpoints= np.array([1,2,6,8])

plt.plot(xpoints,marker='.')
plt.show()

# %%
xpoints= np.array([1,2,6,8])

plt.plot(xpoints,marker='d')
plt.show()

# %%
xpoints= np.array([1,2,6,8])

plt.plot(xpoints,linestyle='dotted')
plt.show()

# %%
xpoints= np.array([1,2,6,8])

plt.plot(xpoints,linestyle='dashed')
plt.show()

# %%
xpoints= np.array([1,2,6,8])

plt.plot(xpoints,linestyle=':')
plt.show()

# %%
xpoints= np.array([1,2,6,8])

plt.plot(xpoints,color='r')
plt.show()

# %%
xpoints= np.array([1,2,6,8])

plt.plot(xpoints,color='hotpink')
plt.show()

# %%
xpoints= np.array([1,2,6,8])

plt.plot(xpoints,linewidth='20.25')
plt.show()

# %%
y1= np.array([1,2,6,8])
y2= np.array([3,6,1,10])
plt.plot(y1,y2)
plt.show()

# %%
x=np.array([80,85,90,100,110,120,125])
y=np.array([240,250,260,270,280,300,320])
plt.plot(x,y)
plt.xlabel("AI")
plt.ylabel("ML")
plt.show()

# %%
x=np.array([80,85,90,100,110,120,125])
y=np.array([240,250,260,270,280,300,320])
font1 ={'family': 'arial','color':'blue','size':20}
font2 ={'family': 'serif','color':'darkred','size':15}

plt.title("sports watch Data",fontdict=font1)
plt.xlabel("Average pulse",fontdict=font2)
plt.xlabel("Calorie Burnage",fontdict=font2)
plt.ylabel("ML")
plt.plot(x,y)
plt.show()

# %%
x=np.array([80,85,90,100,110,120,125])
y=np.array([240,250,260,270,280,300,320])
font1 ={'family': 'arial','color':'blue','size':20}
font2 ={'family': 'serif','color':'darkred','size':15}

plt.title("student data set",fontdict=font1)
plt.xlabel("Bilal Hussain",fontdict=font2)
plt.xlabel("Age",fontdict=font2)
plt.ylabel("Bilal")
plt.plot(x,y)
plt.show()

# %%
x=np.array([80,85,90,100,110,120,125])
y=np.array([240,250,260,270,280,300,320])
font1 ={'family': 'arial','color':'blue','size':20}
font2 ={'family': 'serif','color':'darkred','size':15}

plt.title("sports watch Data",fontdict=font1)
plt.xlabel("Average pulse",fontdict=font2)
plt.xlabel("Calorie Burnage",fontdict=font2)
plt.ylabel("ML")
plt.plot(x,y)
plt.show()

# %%
# %pip install pandas 
# %pip install numpy
# %pip insttall matpoltlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "insttall" - maybe you meant "install"

# %%
import pandas as pd 
import numpy as np
import  matplotlib.pyplot as plt

# %%
pd.read_excel('data.xlsx')
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
df=pd.read_excel('data.xlsx')

# %%
df
# Out:
#              Name Designation Gender    Age     Salary
# 0         Mukhtar   Professor      M   37.0   115000.0
# 1           Azziz     Teacher      M   30.0    35000.0
# 2          Mohsin    Engineer      M   29.0    50000.0
# 3   Naveed Fatima     Analyst      F   30.0    70000.0
# 4           Babar    Engineer      F   25.0  1500000.0
# 5            Aqsa   Scientist      F   22.0        NaN
# 6           Rafia     Analyst      F   29.0    20000.0
# 7           Samra   Scientist      F   26.0   115000.0
# 8            Eman    Engineer      F   28.0    35000.0
# 9        Abdullah     Teacher      M   55.0        NaN
# 10          Mosib   professor      M   60.0    70000.0
# 11          Ahmed    engineer      M    NaN    90000.0
# 12          Ahsan     trainer      M  156.0   110000.0
# 13          Wajid     teacher      M   67.0     2000.0
# 14          Naeem     trainer      M   80.0    16000.0
# 15         Qaisar   professor      M   20.0   170000.0
# ...

# %%
x=df['Age']
y=df['Salary']
plt.plot(x,y, marker='s')
font1={'family': 'arial','color':'blue','size':20}
font2={'family': 'serif','color':'darkred','size':15}
font3={'family': 'arial','color':'pink','size':20}
plt.title('AI&ML',fontdict=font1)
plt.xlabel('Age',fontdict=font2)
plt.ylabel('Salary',fontdict=font3)
plt.show()

# %%
x=df['Age']
y=df['Salary']
plt.plot(x,y, marker='s')
font1={'family': 'arial','color':'blue','size':20}
font2={'family': 'serif','color':'darkred','size':15}
font3={'family': 'arial','color':'pink','size':20}
plt.title('AI&ML',fontdict=font1)
plt.xlabel('Age',fontdict=font2)
plt.ylabel('Salary',fontdict=font3)
plt.grid()
plt.show()

# %%
x=df['Age']
y=df['Salary']
plt.plot(x,y, marker='s')
font1={'family': 'arial','color':'blue','size':20}
font2={'family': 'serif','color':'darkred','size':15}
font3={'family': 'arial','color':'pink','size':20}
plt.title('AI&ML',fontdict=font1)
plt.xlabel('Age',fontdict=font2)
plt.ylabel('Salary',fontdict=font3)
plt.grid(axis="x")
plt.show()

# %%
x=df['Age']
y=df['Salary']
plt.plot(x,y, marker='s')
font1={'family': 'arial','color':'blue','size':20}
font2={'family': 'serif','color':'darkred','size':15}
font3={'family': 'arial','color':'pink','size':20}
plt.title('AI&ML',fontdict=font1)
plt.xlabel('Age',fontdict=font2)
plt.ylabel('Salary',fontdict=font3)
plt.grid(axis="y")
plt.show()

# %%
x=df['Age']
y=df['Salary']
plt.plot(x,y, marker='s',linewidth='05')
font1={'family': 'arial','color':'blue','size':20}
font2={'family': 'serif','color':'darkred','size':15}
font3={'family': 'arial','color':'pink','size':20}
plt.title('AI&ML',fontdict=font1)
plt.xlabel('Age',fontdict=font2)
plt.ylabel('Salary',fontdict=font3)
plt.grid(axis='x',color='blue', linestyle='--',linewidth='05')
plt.grid(axis='y',color='red', linestyle='--',linewidth='08')
plt.show()
